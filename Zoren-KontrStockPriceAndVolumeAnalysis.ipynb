# %%
##required libraries for analysis

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
zoren = yf.Ticker("ZOREN.IS")
kontr = yf.Ticker("KONTR.IS")

# %%
data = yf.download("ZOREN.IS", period="max")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
zoren = zoren.history(period="max")
kontr = kontr.history(period="max")

# %%
zoren.index
# Out:
# DatetimeIndex(['2000-05-26 00:00:00+03:00', '2000-06-02 00:00:00+03:00',
#                '2000-06-06 00:00:00+03:00', '2000-06-09 00:00:00+03:00',
#                '2000-06-12 00:00:00+03:00', '2000-06-13 00:00:00+03:00',
#                '2000-06-14 00:00:00+03:00', '2000-06-15 00:00:00+03:00',
#                '2000-06-16 00:00:00+03:00', '2000-06-19 00:00:00+03:00',
#                ...
#                '2023-10-03 00:00:00+03:00', '2023-10-04 00:00:00+03:00',
#                '2023-10-05 00:00:00+03:00', '2023-10-06 00:00:00+03:00',
#                '2023-10-09 00:00:00+03:00', '2023-10-10 00:00:00+03:00',
#                '2023-10-11 00:00:00+03:00', '2023-10-12 00:00:00+03:00',
#                '2023-10-13 00:00:00+03:00', '2023-10-16 00:00:00+03:00'],
#               dtype='datetime64[ns, Europe/Istanbul]', name='Date', length=5920, freq=None)

# %%
zoren.plot.line(y = "Open", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
kontr.index
# Out:
# DatetimeIndex(['2020-10-19 00:00:00+03:00', '2020-10-20 00:00:00+03:00',
#                '2020-10-21 00:00:00+03:00', '2020-10-22 00:00:00+03:00',
#                '2020-10-23 00:00:00+03:00', '2020-10-26 00:00:00+03:00',
#                '2020-10-27 00:00:00+03:00', '2020-10-28 00:00:00+03:00',
#                '2020-10-30 00:00:00+03:00', '2020-11-02 00:00:00+03:00',
#                ...
#                '2023-10-03 00:00:00+03:00', '2023-10-04 00:00:00+03:00',
#                '2023-10-05 00:00:00+03:00', '2023-10-06 00:00:00+03:00',
#                '2023-10-09 00:00:00+03:00', '2023-10-10 00:00:00+03:00',
#                '2023-10-11 00:00:00+03:00', '2023-10-12 00:00:00+03:00',
#                '2023-10-13 00:00:00+03:00', '2023-10-16 00:00:00+03:00'],
#               dtype='datetime64[ns, Europe/Istanbul]', name='Date', length=749, freq=None)

# %%
zoren = zoren.loc["2020-03-01 00:00:00+03:00":].copy()
kontr = kontr.loc["2020-03-01 00:00:00+03:00":].copy()

# %%
zoren
# Out:
#                            Open  High   Low  Close     Volume  Dividends  \
# Date
# 2020-03-02 00:00:00+03:00  1.37  1.44  1.36   1.40   20072079        0.0
# 2020-03-03 00:00:00+03:00  1.43  1.47  1.42   1.45   16603242        0.0
# 2020-03-04 00:00:00+03:00  1.44  1.51  1.41   1.43   45384338        0.0
# 2020-03-05 00:00:00+03:00  1.44  1.47  1.43   1.44   15255433        0.0
# 2020-03-06 00:00:00+03:00  1.43  1.45  1.38   1.40   15381632        0.0
# ...                         ...   ...   ...    ...        ...        ...
# 2023-10-10 00:00:00+03:00  6.26  6.76  6.26   6.39  536833728        0.0
# 2023-10-11 00:00:00+03:00  6.48  6.56  6.16   6.16  284683099        0.0
# 2023-10-12 00:00:00+03:00  6.30  6.57  5.98   6.33  383278737        0.0
# 2023-10-13 00:00:00+03:00  6.35  6.52  6.23   6.24  294784445        0.0
# 2023-10-16 00:00:00+03:00  6.38  6.49  6.18   6.17  312162260        0.0
#
#                            Stock Splits
# Date
# ...

# %%
kontr
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-10-19 00:00:00+03:00    1.435247    1.435247    1.435247    1.435247
# 2020-10-20 00:00:00+03:00    1.577071    1.577071    1.577071    1.577071
# 2020-10-21 00:00:00+03:00    1.734021    1.734021    1.734021    1.734021
# 2020-10-22 00:00:00+03:00    1.906100    1.906100    1.906100    1.906100
# 2020-10-23 00:00:00+03:00    2.095197    2.095197    2.095197    2.095197
# ...                               ...         ...         ...         ...
# 2023-10-10 00:00:00+03:00  292.899994  316.399994  292.899994  316.399994
# 2023-10-11 00:00:00+03:00  320.200012  324.000000  307.100006  307.100006
# 2023-10-12 00:00:00+03:00  318.299988  321.600006  292.799988  300.700012
# 2023-10-13 00:00:00+03:00  301.500000  304.299988  292.000000  293.299988
# 2023-10-16 00:00:00+03:00  302.299988  304.399994  278.500000  280.500000
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
zoren.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
kontr.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock = ["KONTR.IS", "ZOREN.IS"]
stocks = yf.download(stock, start="2020-10-18", end="2023-10-16")
datas = stocks.loc[:, "Close"].copy()
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
datas.plot(figsize=(17,8), fontsize=18)
plt.style.use("seaborn")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
stock = ["ZOREN.IS"]
stocks = yf.download(stock, start="2023-09-01", end="2023-10-16")
datas = stocks.loc[:, "Close"].copy()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
datas.plot(figsize=(17,8), fontsize=18)
plt.style.use("seaborn")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import mplfinance as mpf

# %%
mpf.plot(stocks,type='candle')

# %%
mpf.plot(stocks,type='candle',mav=4)

# %%
mpf.plot(stocks,type='candle',mav=(2,4,6),volume=True)

# %%
stockkontr = ["KONTR.IS"]
stockkontrs = yf.download(stockkontr, start="2023-09-01", end="2023-10-16")
datakontr = stockkontrs.loc[:, "Close"].copy()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
datakontr.plot(figsize=(17,8), fontsize=18)
plt.style.use("seaborn")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mpf.plot(stockkontrs, type="candle")

# %%
mpf.plot(stockkontrs, type='candle',mav=(2,4,6),volume=True)

# %%
kontr.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>
